# %%
import geopandas as gpd

# Reading the data
world_loans = gpd.read_file('/home/jake_ockerby/Python/kiva_loans/kiva_loans.shp')
world_loans.head()
# Out:
#    Partner ID                       Field Part                       sector  \
# 0           9  KREDIT Microfinance Institution  General Financial Inclusion
# 1           9  KREDIT Microfinance Institution  General Financial Inclusion
# 2           9  KREDIT Microfinance Institution  General Financial Inclusion
# 3           9  KREDIT Microfinance Institution  General Financial Inclusion
# 4           9  KREDIT Microfinance Institution  General Financial Inclusion
#
#                Loan Theme   country  amount                    geometry
# 0        Higher Education  Cambodia     450  POINT (102.89751 13.66726)
# 1  Vulnerable Populations  Cambodia   20275  POINT (102.98962 13.02870)
# 2        Higher Education  Cambodia    9150  POINT (102.98962 13.02870)
# 3  Vulnerable Populations  Cambodia  604950  POINT (105.31312 12.09829)
# 4              Sanitation  Cambodia     275  POINT (105.31312 12.09829)

# %%
# Loading the GeoDataFrame containing country boundries
world_filepath = gpd.datasets.get_path('naturalearth_lowres')
world = gpd.read_file(world_filepath)
world
# Out:
#        pop_est                continent                      name iso_a3  \
# 0       920938                  Oceania                      Fiji    FJI
# 1     53950935                   Africa                  Tanzania    TZA
# 2       603253                   Africa                 W. Sahara    ESH
# 3     35623680            North America                    Canada    CAN
# 4    326625791            North America  United States of America    USA
# 5     18556698                     Asia                Kazakhstan    KAZ
# 6     29748859                     Asia                Uzbekistan    UZB
# 7      6909701                  Oceania          Papua New Guinea    PNG
# 8    260580739                     Asia                 Indonesia    IDN
# 9     44293293            South America                 Argentina    ARG
# 10    17789267            South America                     Chile    CHL
# 11    83301151                   Africa           Dem. Rep. Congo    COD
# ...

# %%
# Plotting kiva loans locations on the world map
ax = world.plot(figsize=(20,20), color='whitesmoke', linestyle=':', edgecolor='black')
world_loans.plot(ax=ax, markersize=2)

# %%
# Loading file containing map of the Phillippines

PHL_loans = world_loans.loc[world_loans.country=="Philippines"].copy()
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
PHL = gpd.read_file('/home/jake_ockerby/Python/kiva_loans/Philippines_AL258.kml', driver='KML')
PHL.head()
# Out:
#                                    Name Description  \
# 0  Autonomous Region in Muslim Mindanao
# 1                          Bicol Region
# 2                        Cagayan Valley
# 3                            Calabarzon
# 4                                Caraga
#
#                                             geometry
# 0  MULTIPOLYGON (((119.46690 4.58718, 119.46653 4...
# 1  MULTIPOLYGON (((124.04577 11.57862, 124.04594 ...
# 2  MULTIPOLYGON (((122.51581 17.04436, 122.51568 ...
# 3  MULTIPOLYGON (((120.49202 14.05403, 120.49201 ...
# 4  MULTIPOLYGON (((126.45401 8.24400, 126.45407 8...

# %%
# Plotting kiva loans on map of the Phillippines
ax = PHL.plot(figsize=(12,12), color='whitesmoke', linestyle=':', edgecolor='black')
PHL_loans.plot(ax=ax, markersize=2)

# The map shows there are many places where kiva loans can recruit new field partners
# in the Phillippines, notably Mindoro and eastern Mindanao
